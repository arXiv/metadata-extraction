# %%
import tarfile
import io
import zipfile
import importlib
import regex as re
import pyperclip  
import TexSoup as TS
from TexSoup.tokens import MATH_ENV_NAMES
import os

# %%
import pandas as pd

# Load the datasets
scopus_data = pd.read_csv('data/2201.00_scopus_931.csv')
ror_mapping = pd.read_csv('matching_data/matched_results_fuzzy.csv')

# Merge the datasets on 'Primary Org Id'
merged_data = pd.merge(
    scopus_data,
    ror_mapping,
    on='Primary Org Id',
    how='left'  # Use 'left' to keep all rows from scopus_data even if no match is found
)

# Calculate the number of unmatched rows
unmatched_count = merged_data['ROR ID'].isna().sum()

print(f"Number of unmatched 'Primary Org Id' values: {unmatched_count}")

# Save the merged data to a new CSV file
merged_data.to_csv('data/2201.00_scopus_931_with_ror.csv', index=False)

print("Matching completed. The output is saved as 'data/2201.00_scopus_931_with_ror.csv'.")

import os
import pandas as pd

# Paths
csv_path = 'data/2201.00_scopus_931_with_ror.csv'
text_folder = 'data/2201_00_text'

# Read the CSV file
df = pd.read_csv(csv_path)

# Assuming the column containing ArXiv IDs is named 'ArXiv Id'
arxiv_ids = df['ArXiv Id'].dropna().unique()  # Drop NaN values and get unique IDs

# Initialize counters and a list to store missing files
found_count = 0
total_count = len(arxiv_ids)
missing_files = []

# Check for each ArXiv ID
for arxiv_id in arxiv_ids:
    txt_file_path = os.path.join(text_folder, f"{arxiv_id}.txt")
    if os.path.isfile(txt_file_path):
        found_count += 1
    else:
        missing_files.append(arxiv_id)

# Calculate the percentage
percentage = (found_count / total_count) * 100

# Display results
print(f"Total ArXiv IDs: {total_count}")
print(f"Found text files: {found_count}")
print(f"Percentage: {percentage:.2f}%")
print("\nMissing files:")
for missing_id in missing_files:
    print(missing_id)


import pandas as pd

# Load the CSV file
file_path = 'data/2201.00_scopus_931_with_ror.csv'
df = pd.read_csv(file_path)

# Select the desired columns
columns_to_keep = ['Primary Org Id', 'Primary Org Name_x', 'ArXiv Id', 'ROR ID']
df_selected = df[columns_to_keep]

# Save the preprocessed data to a new CSV file
output_file_path = 'data/preprocessed_scopus_data.csv'
df_selected.to_csv(output_file_path, index=False)

print(f"Preprocessed data saved to {output_file_path}")
# Out:
# Number of unmatched 'Primary Org Id' values: 24
# Matching completed. The output is saved as 'data/2201.00_scopus_931_with_ror.csv'.
# Total ArXiv IDs: 931
# Found text files: 931
# Percentage: 100.00%
#
# Missing files:
# Preprocessed data saved to data/preprocessed_scopus_data.csv

# %%
import pandas as pd
from extractors.trie_extractor import TrieExtractor
from utils.file_reader import read_file
from tqdm import tqdm  # Import tqdm for progress bar

# Load the CSV file
csv_path = "data/2201.00_scopus_931_with_ror.csv"
df = pd.read_csv(csv_path)

# Initialize the TrieExtractor
extractor = TrieExtractor(data_path="data/1.34_extracted_ror_data.csv", common_words_path="data/common_english_words.txt")

# %%
import zipfile
import re
import io

def find_doc_class(fp, name_match=False):
    """Search for document class related lines in a file and return a code to represent the type"""
    doc_class_pat = re.compile(r"^\s*\\document(?:style|class)")
    sub_doc_class = re.compile(r"^\s*\\document(?:style|class).*(?:\{standalone\}|\{subfiles\})")

    file_content = fp.read()
    try:
        file_text = file_content.decode('utf-8')
    except UnicodeDecodeError:
        file_text = file_content.decode('latin-1')

    for line in file_text.splitlines():
        if doc_class_pat.search(line):
            if name_match:
                if sub_doc_class.search(line):
                    return -99999
                return 1  # Found document class line
    return 0  # No document class line found

def find_main_tex_source_in_folder(zip_file, folder_name):
    """Find the main .tex file inside a folder within the zip archive"""
    tex_names = {"paper", "main", "ms.", "article"}
    
    # Get all .tex files in the folder
    tex_files = [f for f in zip_file.namelist() if f.startswith(folder_name + '/') and f.endswith('.tex')]

    if len(tex_files) == 1:
        return tex_files[0]  # If there's only one .tex file, return it

    main_files = {}
    for tex_file in tex_files:
        depth = tex_file.count('/') - folder_name.count('/')  # Depth relative to folder
        has_main_name = any(kw in tex_file for kw in tex_names)
        
        with zip_file.open(tex_file) as fp:
            main_files[tex_file] = find_doc_class(fp, name_match=has_main_name) - depth

    return max(main_files, key=main_files.get) if main_files else None

def pre_format(text):
    """Format LaTeX text by adding spaces where necessary"""
    # return text.replace('\\}\\', '\\} \\').replace(')}', ') }').replace(')$', ') $')
    return text

def source_from_zip(zip_file, folder_name):
    """Extract and decode the main .tex file from a folder inside the zip archive"""
    tex_main = find_main_tex_source_in_folder(zip_file, folder_name)
    if tex_main:
        with zip_file.open(tex_main) as fp:
            file_content = fp.read()
            try:
                source_text = pre_format(file_content.decode('utf-8'))
            except UnicodeDecodeError:
                source_text = pre_format(file_content.decode('latin-1'))
            return source_text
    return None

def extract_before_abstract(source_text):
    """Extract text before the abstract section"""
    no_comments_text = re.sub(r'(?<!\\)%.*', '', source_text)  # Remove comments
    # no_usepackage_text = re.sub(r'\\usepackage\s*\{[^}]+\}', '', no_comments_text)  # Remove usepackage
    # text = re.sub(r'\\[a-zA-Z]+\{[^}]*\}', '', no_usepackage_text)  # Remove LaTeX commands
    text = no_comments_text
    # text = re.sub(r'\\[a-zA-Z]+\[[^\]]*\]\{[^}]*\}', '', text)
    # text = re.sub(r'\$[^$]*\$', '', text)  # Remove inline math
    # text = text.replace('{', '').replace('}', '').replace('\n', ' ')
    text = ' '.join(text.split())

    # output_file.write(f"text: {text}\n")

    abstract_word_match = re.search(r'begin{abstract}', text, re.IGNORECASE)
    if abstract_word_match:
        return text[:abstract_word_match.start()].strip()

    abstract_match = re.search(r'abstract{', text)
    if abstract_match:
        return text[:abstract_match.start()].strip()
    
    nomacro_abstract_match_2 = re.search(r'abstract', text)
    if nomacro_abstract_match_2:
        return text[:nomacro_abstract_match_2.start()].strip()
    
    nomacro_abstract_match_1 = re.search(r'Abstract', text)
    if nomacro_abstract_match_1:
        return text[:nomacro_abstract_match_1.start()].strip()
    
    return None

zip_file_path = "./2311_tex_test.zip"
output_path = "./output.txt"


with zipfile.ZipFile(zip_file_path, 'r') as zip_file:
    base_folder = zip_file.namelist()[0]
    folders = {name.rstrip('/') for name in zip_file.namelist() if name.startswith(base_folder) and name.endswith('/') and name != base_folder}  # Get folder names

    with open(output_path, 'w', encoding='utf-8') as output_file:
        for folder in folders:
            source_text = source_from_zip(zip_file, folder)
            # output_file.write(f"{folder}:source text: {source_text}\n")
            if source_text:
                content_before_abstract = extract_before_abstract(source_text)
                if content_before_abstract:
                    output_file.write(f"Content before abstract in {folder}:\n{content_before_abstract}\n\n")
                else:
                    output_file.write(f"No abstract found in {folder}, or no content before abstract.\n\n")
            else:
                output_file.write(f"No source found in {folder}.\n\n")

# %%
# Read input from a text file and filter out files without valid content before the abstract
input_file_path = 'output.txt'  # Replace with your actual file path
output_file_path = 'filtered_files_with_content_macro.txt'

# Variables to keep track of statistics
total_files_count_author = 0
valid_files_count = 0
valid_files_with_content = []

# Reading and processing the input file
with open(input_file_path, 'r') as infile:
    content_blocks = infile.read().split('Content before abstract in ')
    
    for block in content_blocks:
        if block.strip():  # Ensure we are not processing an empty block
            total_files_count_author += 1
            lines = block.split('\n', 1)  # Split to separate the file name from its content
            if len(lines) > 1:
                file_name = lines[0].strip().replace(':', '')
                content = lines[1].strip()
                
                # Check if the content does not indicate "No abstract found"
                if 'No abstract found' not in content and 'no content before abstract' not in content.lower():
                    valid_files_count += 1
                    valid_files_with_content.append((file_name, content))

# Writing the filtered results to an output file
with open(output_file_path, 'w') as outfile:
    for file_name, content in valid_files_with_content:
        outfile.write(f"Content before abstract in {file_name}:\n{content}\n\n")

# Print or save the statistics summary
print(f"Total number of files processed: {total_files_count_author}")
print(f"Total number of files with valid content before abstract: {valid_files_count}")
print(f"Filtered output saved in: {output_file_path}")
# Out:
# Total number of files processed: 82
# Total number of files with valid content before abstract: 78
# Filtered output saved in: filtered_files_with_content_macro.txt

# %%
import re
import os
import json  # For structured storage

# Define file paths
input_file_path = 'filtered_files_with_content_macro.txt'
output_file_path = './tagged_outputs/all_extracted_tags_cleaned.txt'  # Single output file

# Ensure output directory exists
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

# Tags to search for (without leading backslashes for dictionary keys)
tags_to_search = [
    'orgname','institution', 'affiliations', 'affiliation', 'icmlaffiliation',
    'institute', 'affil', 'aff', 'AFF', 'university', 'address'
]

# Dictionary to store extracted data
extracted_data = {}

# Function to extract content inside the first level of braces `{}` (handling optional `[]`)
def extract_tag_content(tag, content):
    pattern = rf"(\\{tag})(\[[^\]]*\])?\{{"
    results = []
    start = 0

    while (match := re.search(pattern, content[start:])) is not None:
        start_idx = start + match.end()  # Start after the macro (past `{`)
        brace_level = 1
        end_idx = start_idx

        # Find the matching closing brace
        while brace_level > 0 and end_idx < len(content):
            if content[end_idx] == '{':
                brace_level += 1
            elif content[end_idx] == '}':
                brace_level -= 1
            end_idx += 1

        # Extract only the content inside the first `{}` (excluding the macro name)
        extracted_content = content[start_idx:end_idx - 1].strip()  # Remove trailing `}`
        results.append(extracted_content)
        start = end_idx  # Move to next occurrence

    return results

# Function to process and store extracted content
def extract_and_store_tags(file_name, content, tags):
    extracted_data[file_name] = {}  # Initialize storage for this file
    found_any_tag = False  # Flag to check if we found any tag

    for tag in tags:
        matches = extract_tag_content(tag, content)

        if matches:
            extracted_data[file_name][tag] = matches  # Store under cleaned key
            found_any_tag = True  # At least one macro was found
            break

    # If no macros were found, store the whole pre-abstract content
    if not found_any_tag:
        extracted_data[file_name]["full_content"] = content

# Process input file
total_files_count = 0

with open(input_file_path, 'r') as infile:
    content_blocks = infile.read().split('Content before abstract in ')

    for block in content_blocks:
        if block.strip():
            total_files_count += 1
            lines = block.split('\n', 1)

            if len(lines) > 1:
                file_name = lines[0].strip().replace(':', '')
                content = lines[1].strip()
                extract_and_store_tags(file_name, content, tags_to_search)

json_output = json.dumps(extracted_data, indent=4, ensure_ascii=False)
# json_output = json_output.replace("\\\\", "\\")  # Convert double backslashes to single

with open(output_file_path, 'w', encoding='utf-8') as outfile:
    outfile.write(json_output)


# Print summary
print(f"Total number of files processed: {total_files_count}")
print(f"Extracted tag data saved in: {output_file_path}")
# Out:
# Total number of files processed: 78
# Extracted tag data saved in: ./tagged_outputs/all_extracted_tags_cleaned.txt

# %%
import requests
import json
import logging
import os
from tenacity import retry, stop_after_attempt, wait_fixed

# Configure logging
logging.basicConfig(level=logging.INFO)

# Configure ROR API information
ROR_SEARCH_URL = 'https://api.ror.org/organizations'

# Initialize ROR cache
ror_cache = {}

# Load persistent cache
cache_file = 'ror_cache.json'
if os.path.exists(cache_file):
    with open(cache_file, 'r', encoding='utf-8') as f:
        ror_cache = json.load(f)
    logging.info("Loaded persistent ROR cache.")
else:
    logging.info("No persistent ROR cache found. Using empty cache.")

@retry(stop=stop_after_attempt(3), wait=wait_fixed(5))
def query_ror(institution_name):
    """
    Query ROR information, returning details from the first result in the response.
    """
    if institution_name in ror_cache:
        return ror_cache[institution_name]
    
    params = {'query': institution_name}

    try:
        response = requests.get(ROR_SEARCH_URL, params=params, timeout=10)
        if response.status_code == 200:
            data = response.json()
            if data.get('items'):
                first_result = data['items'][0]  # Get the first search result
                
                ror_cache[institution_name] = {
                    'ROR_ID': first_result.get('id', 'N/A'),
                    'Name': first_result.get('name', 'N/A'),
                    'Country': first_result.get('country', {}).get('country_name', 'N/A'),
                    'Type': ', '.join(first_result.get('types', []))
                }
                logging.info(f"First ROR result found for '{institution_name}': {first_result.get('name', 'N/A')}")
                return ror_cache[institution_name]

            else:
                logging.warning(f"No ROR information found for '{institution_name}'.")
                ror_cache[institution_name] = None
                return None
        else:
            logging.error(f"ROR API query failed with status code: {response.status_code} for institution: {institution_name}")
            ror_cache[institution_name] = None
            return None
    except Exception as e:
        logging.error(f"ROR API query exception for '{institution_name}', Error: {e}")
        ror_cache[institution_name] = None
        return None


# Save cache to a file after all queries
def save_cache():
    with open(cache_file, 'w', encoding='utf-8') as f:
        json.dump(ror_cache, f)
    logging.info("Saved ROR cache to file.")
# Out:
# INFO:root:Loaded persistent ROR cache.

# %%
import json
import os
from extractors.trie_extractor import TrieExtractor
from utils.file_reader import read_file

# Define file paths
input_file_path = 'tagged_outputs/all_extracted_tags_cleaned.txt'
output_file_path = 'institution_output_with_ror.json'

# Read the file and replace invalid escape sequences
with open(input_file_path, 'r', encoding='utf-8') as infile:
    raw_data = infile.read()

# Fix invalid escape sequences by double-escaping backslashes
# fixed_data = raw_data.replace("\\", "\\\\")
fixed_data = raw_data

# Try loading again
try:
    extracted_data = json.loads(fixed_data)
    print("✅ JSON successfully loaded!")
except json.JSONDecodeError as e:
    print(f"❌ JSON loading failed: {e}")
# Out:
# ✅ JSON successfully loaded!

# %%
# Load TrieExtractor for full content/address processing
extractor = TrieExtractor(
    data_path="data/1.34_extracted_ror_data.csv",
    common_words_path="data/common_english_words.txt"
)

# %%
import re
import spacy
# Load the spaCy model for Named Entity Recognition (NER)
nlp = spacy.load("en_core_web_sm")

# %%
abname = ' $^1$ Robotics and Artificial Intelligence Group, Department of Computer Science, Electrical and Space Engineering, Lule\aa \,\, University of Technology, Sweden (e-mail: (vissan, sumsat, geonik)@ltu.se)'
abname = re.sub(r'\b(Faculty of|Department of|School of|College of)\b[^,]*,', '', abname, flags=re.IGNORECASE)
print(abname)
# Out:
#  $^1$ Robotics and Artificial Intelligence Group,  Electrical and Space Engineering, Lulea \,\, University of Technology, Sweden (e-mail: (vissan, sumsat, geonik)@ltu.se)

# %%
stringa = "$^*$Physics Department, Arizona State University, Tempe, Arizona 85287, USA.\\\\ $^\\dag$Theoretical Physics Department, CERN, 1211 Geneva 23, Switzerland."
print(latex_to_unicode(stringa))
# Out:
# ^*Physics Department, Arizona State University, Tempe, Arizona 85287, USA.
#  ^†Theoretical Physics Department, CERN, 1211 Geneva 23, Switzerland.

# %%
def remove_address_spacy(text):
    """Uses spaCy NER to remove location entities from an institution name"""
    doc = nlp(text)
    cleaned_parts = []
    
    for ent in doc.ents:
        if ent.label_ in {"GPE", "LOC"}:  # GPE = Geo-Political Entity (City, Country, etc.)
            continue  # Skip locations
        cleaned_parts.append(ent.text)

    return " ".join(cleaned_parts)

from pylatexenc.latex2text import LatexNodes2Text

converter = LatexNodes2Text()

def latex_to_unicode(text):
    """Safely converts LaTeX special characters to Unicode, handling errors."""
    if not text or text.strip() == "":
        return ""  # Avoid empty input issues
    
    try:
        return converter.latex_to_text(text)
    except IndexError as e:
        print(f"⚠️ Warning: Error parsing LaTeX in text: {text}")
        print("\n⚠️ latex_to_unicode parse error encountered!")
        print("Full input string:")
        print("--------------------------------------------------")
        print(text)
        print("--------------------------------------------------")
        print(f"Error message: {e}\n")
        return text  # fallback: just return the original text
    
import re

def mild_clean_affiliation(affiliation):
    parts = [p.strip() for p in affiliation.split(',')]
    if len(parts) > 3:
        # If any part contains 'university', return that part + next part (if exists)
        for i, part in enumerate(parts):
            if 'university' in part.lower():
                if i < len(parts) - 1:
                    return f"{part}, {parts[i+1]}"
                else:
                    return part
        # If no 'university' found, fallback to original logic
        affiliation = ', '.join(parts[:3])
    return affiliation.strip()

import re



def split_affiliations_before_unicode(raw_text):
    pattern = re.compile(r'(\$\\?\^(?:\\dag|\\star|\*|\d+))')
    positions = [m.start() for m in pattern.finditer(raw_text)] + [len(raw_text)]

    results = []
    for i in range(len(positions) - 1):
        segment = raw_text[positions[i]:positions[i+1]].strip()
        cleaned_segment = pattern.sub('', segment, count=1).strip()
        if cleaned_segment:
            results.append(cleaned_segment)

    return results

# 测试案例
stringa = r"$^*$Physics Department, Arizona State University, Tempe, Arizona 85287, USA. \\ $^\\dag$Theoretical Physics Department, CERN, 1211 Geneva 23, Switzerland."

print("\nOriginal input:")
print(stringa)

split_result = split_affiliations_before_unicode(stringa)

print("\nSplit affiliations before unicode:")
for idx, aff in enumerate(split_result, 1):
    print(f"Institution {idx}: {aff}")
# Out:
# Original input:
# $^*$Physics Department, Arizona State University, Tempe, Arizona 85287, USA. \\ $^\\dag$Theoretical Physics Department, CERN, 1211 Geneva 23, Switzerland.
#
# Split affiliations before unicode:
# Institution 1: $Physics Department, Arizona State University, Tempe, Arizona 85287, USA. \\ $^\\dag$Theoretical Physics Department, CERN, 1211 Geneva 23, Switzerland.

# %%
import re
from pylatexenc.latex2text import LatexNodes2Text

converter = LatexNodes2Text()

def remove_address_spacy(text):
    """Uses spaCy NER to remove location entities from an institution name"""
    doc = nlp(text)
    cleaned_parts = []

    for ent in doc.ents:
        if ent.label_ in {"GPE", "LOC"}:
            continue  # Skip locations
        cleaned_parts.append(ent.text)

    return " ".join(cleaned_parts)

def latex_to_unicode(text):
    """Safely converts LaTeX special characters to Unicode, handling errors."""
    if not text or text.strip() == "":
        return ""  # Avoid empty input issues

    try:
        return converter.latex_to_text(text)
    except IndexError as e:
        print(f"⚠️ Warning: Error parsing LaTeX in text: {text}")
        print("\n⚠️ latex_to_unicode parse error encountered!")
        print("Full input string:")
        print("--------------------------------------------------")
        print(text)
        print("--------------------------------------------------")
        print(f"Error message: {e}\n")
        return text  # fallback: just return the original text

def mild_clean_affiliation(affiliation):
    parts = [p.strip() for p in affiliation.split(',')]
    if len(parts) > 3:
        for i, part in enumerate(parts):
            if 'university' in part.lower():
                if i < len(parts) - 1:
                    return f"{part}, {part}, {parts[i+1]}"
                else:
                    return part
        affiliation = ', '.join(parts[:3])
    return affiliation.strip()


def split_affiliations_before_unicode(raw_text):
    temp_text = re.sub(r'(\\?\\?\$\\?\\^)(\\?\\dag|\\?\\star|\\?\*|\\?\\)', r'$^SPECIAL', raw_text)
    split_result = re.split(r'\\?\\?\$\\?\\^(?:SPECIAL|\d+)', temp_text)
    cleaned = [chunk.strip(' .\\') for chunk in split_result if chunk.strip()]
    return cleaned

stringa1 = r"$^*$Physics Department, Arizona State University, Tempe, Arizona 85287, USA. \\ $^\\dag$Theoretical Physics Department, CERN, 1211 Geneva 23, Switzerland."
stringa2 = r"$^1$ Robotics and Artificial Intelligence Group, Department of Computer Science, Electrical and Space Engineering, Lule\\aa \,\, University of Technology, Sweden (e-mail: (vissan, sumsat, geonik)@ltu.se) \\ $^2$ Department of Computer Science, University of Helsinki, Finland."

print("\nOriginal input:")
print(stringa2)

split_result = split_affiliations_before_unicode(stringa2)

print("\nSplit affiliations before unicode:")
for idx, aff in enumerate(split_result, 1):
    print(f"Institution {idx}: {aff}")
# Out:
# Original input:
# $^1$ Robotics and Artificial Intelligence Group, Department of Computer Science, Electrical and Space Engineering, Lule\\aa \,\, University of Technology, Sweden (e-mail: (vissan, sumsat, geonik)@ltu.se) \\ $^2$ Department of Computer Science, University of Helsinki, Finland.
#
# Split affiliations before unicode:
# Institution 1: $^1$ Robotics and Artificial Intelligence Group, Department of Computer Science, Electrical and Space Engineering, Lule\\aa \,\, University of Technology, Sweden (e-mail: (vissan, sumsat, geonik)@ltu.se) \\ $^2$ Department of Computer Science, University of Helsinki, Finland

# %%
results = {}
# Process each paper
for paper, macros in extracted_data.items():
    unique_rors = {}  # Dictionary to store unique ROR results

    if isinstance(macros, dict) and set(macros.keys()) in [{"full_content"}, {"address"}]:
        # Extract RORs from full content or address
        text = "\n".join(macros.get("full_content", [])) + "\n" + "\n".join(macros.get("address", []))
        text = latex_to_unicode(text)
        extracted_ror_ids = extractor.extract_affiliations(text)

        if extracted_ror_ids:
            unique_rors.update({ror_id: {"ROR_ID": ror_id} for ror_id in extracted_ror_ids})

    else:
        for content_list in macros.values():
            for institution_name in content_list:
                # Remove possible '{' and '}' characters
                # cleaned_name = institution_name.replace("{", " ").replace("}", " ").replace("^"," ").replace("["," ").replace("]"," ").strip()
                # cleaned_name = latex_to_unicode(cleaned_name)
                # # cleaned_name = cleaned_name.translate(str.maketrans('', '', '{}"')).strip()
                # # cleaned_name = re.sub(r'^(Department of|School of|Faculty of)?\s*([\w\s&-]+),', '', cleaned_name, flags=re.IGNORECASE)


                # cleaned_name = cleaned_name.replace("{", " ").replace("}", " ").replace("^"," ").replace("["," ").replace("]"," ").strip()

                
                # # Remove department prefixes
                # cleaned_name = re.sub(r'^(.*?\b(Department of|School of|Faculty of|College of)\b[^,]*),', '', cleaned_name, flags=re.IGNORECASE)

                cleaned_name = latex_to_unicode(institution_name)
                split_institutions = re.split(r'\s*\^\d+', cleaned_name)
                split_institutions = [inst.strip() for inst in split_institutions if inst.strip()]

                # Strict: only split on '^\d' to separate multiple affiliations


                for institution in split_institutions:
                    institution = institution.replace("{", " ").replace("}", " ").replace("^"," ").replace("["," ").replace("]"," ").strip()

                    institution = mild_clean_affiliation(institution)
                    institution = re.sub(r'^(.*?\b(Department of|School of|Faculty of|College of|Department)\b[^,]*),', '', institution, flags=re.IGNORECASE)

                    ror_info = query_ror(institution)
                    if ror_info:
                        unique_rors[ror_info["ROR_ID"]] = ror_info  # Store unique RORs

                # cleaned_name = mild_clean_affiliation(cleaned_name)
                # # Remove department prefixes
                # cleaned_name = re.sub(r'^(.*?\b(Department of|School of|Faculty of|College of|Department)\b[^,]*),', '', cleaned_name, flags=re.IGNORECASE)
                # # cleaned_name = remove_address_spacy(cleaned_name)


                # ror_info = query_ror(cleaned_name)
                # if ror_info:
                #     unique_rors[ror_info["ROR_ID"]] = ror_info  # Store unique RORs

    # Save results if there are ROR matches
    if unique_rors:
        results[paper] = list(unique_rors.values())  # Convert to list for JSON storage

# Save results to JSON file
with open(output_file_path, 'w', encoding='utf-8') as outfile:
    json.dump(results, outfile, indent=4, ensure_ascii=False)

print(f"✅ JSON export completed. Results saved to {output_file_path}")
# Out:
# INFO:root:First ROR result found for 'Swansea University, Swansea University, Swansea SA2 8PP': Swansea University
# INFO:root:First ROR result found for 'Tsinghua University, Tsinghua University, Beijing': Tsinghua University
# INFO:root:First ROR result found for 'KTH Royal Institute of Technology and Stockholm University, KTH Royal Institute of Technology and Stockholm University, Hannes Alfvéns Väg 12': KTH Royal Institute of Technology
# INFO:root:First ROR result found for 'Copenhagen University, Copenhagen University, Blegdamsvej 17': University of Copenhagen
# INFO:root:First ROR result found for 'Florida Atlantic University, Florida Atlantic University, Boca Raton': Florida Atlantic University
# INFO:root:First ROR result found for 'Akdeniz University, Akdeniz University, Faculty of Sciences': Akdeniz University
# INFO:root:First ROR result found for 'Istanbul University, Istanbul University, Faculty of Science': Istanbul University
# INFO:root:First ROR result found for 'Nielsen, 675 6th Ave, New York': Atlas of Variant Effects Alliance
# INFO:root:First ROR result found for 'Dept. of Physical Science & Engineering, Harper College, 1200 W Algonquin Rd': Algonquin College
# INFO:root:First ROR result found for 'York University, York University, Toronto': York University
# INFO:root:First ROR result found for 'Stockholm University, Stockholm University, Stockholm 106 91': Stockholm University
# INFO:root:First ROR result found for 'Dipartimento Interateneo di Fisica “Michelangelo Merlin, ” Via Amendola 173, 70126 Bari': Istituto Nazionale di Fisica Nucleare, Sezione di Bari
# INFO:root:First ROR result found for 'Istituto Nazionale di Fisica Nucleare - Sezione di Bari, Via Orabona 4, 70126 Bari': Istituto Nazionale di Fisica Nucleare, Sezione di Bari
# INFO:root:First ROR result found for 'Institut für Theoretische Physik, Universität Heidelberg, Philosophenweg 16': Institute for Theoretical Physics
# INFO:root:First ROR result found for 'Universität Heidelberg, Kirchhoff-Institut für Physik, Im Neuenheimer Feld 227': Institute for Theoretical Physics
# INFO:root:First ROR result found for 'Dipartimento di Fisica “E.R. Caianiello”, Università degli Studi di Salerno, Via Giovanni Paolo II': University of Salerno
# INFO:root:First ROR result found for 'INFN - Gruppo Collegato di Salerno, Via Giovanni Paolo II, 132 - 84084 Fisciano (SA)': Istituto Nazionale di Fisica Nucleare, Gruppo Collegato di Salerno
# INFO:root:First ROR result found for 'LAPTh, CNRS, USMB': Laboratoire d'Annecy-le-Vieux de Physique Théorique
# INFO:root:First ROR result found for 'The Pennsylvania State University, The Pennsylvania State University, University Park PA 16802': Pennsylvania State University
# INFO:root:First ROR result found for 'University of California, University of California, Berkeley': University of California, Berkeley
# INFO:root:First ROR result found for 'Theoretisch-Physikalisches Institut, Friedrich-Schiller-Universität Jena, 07743': Friedrich Schiller University Jena
# INFO:root:First ROR result found for 'Dipartimento di Fisica, Università di Trento, Via Sommarive 14': University of Trento
# INFO:root:First ROR result found for 'INFN-TIFPA, Trento Institute for Fundamental Physics and Applications, via Sommarive 14': Istituto Nazionale di Fisica Nucleare, Trento Institute for Fundamental Physics And Applications
# INFO:root:First ROR result found for 'Ohio State University': Ohio State University Hospital
# INFO:root:First ROR result found for ' Institute for Advanced Studies in Basic Sciences (IASBS), Zanjan 45137‑66731': Institute for Advanced Studies in Basic Sciences
# INFO:root:First ROR result found for 'Optics Research Center, Institute for Advanced Studies in Basic Sciences (IASBS), Zanjan 45137-66731': Institute for Advanced Studies in Basic Sciences
# INFO:root:First ROR result found for 'P.N. Lebedev Institute of Physics, Lenin Avenue 53, 119991 Moscow': P.N. Lebedev Physical Institute of the Russian Academy of Sciences
# INFO:root:First ROR result found for 'Lomonosov Moscow State University, Lomonosov Moscow State University, 119991 Moscow': Lomonosov Moscow State University
# INFO:root:First ROR result found for 'Joint Institute for Nuclear Research, Dubna 141980, Moscow region': Joint Institute for Nuclear Research
# INFO:root:First ROR result found for 'University of California Santa Barbara, University of California Santa Barbara, Santa Barbara': University of California, Santa Barbara
# INFO:root:First ROR result found for 'University of Amsterdam, University of Amsterdam, Science Park 904': University of Amsterdam
# INFO:root:First ROR result found for 'Delta Institute for Theoretical Physics, Science Park 904, PO Box 94485': Delta Institute for Theoretical Physics
# INFO:root:First ROR result found for 'Clarkson University': Clarkson University
# INFO:root:First ROR result found for 'Universidade de São Paulo': Universidade de São Paulo
# INFO:root:First ROR result found for 'Wake Forest University School of Medicine': Wake Forest University
# WARNING:root:No ROR information found for 'yyy'.
# INFO:root:First ROR result found for 'Arizona State University, Arizona State University, Tempe': Arizona State University
# INFO:root:First ROR result found for 'University of Aveiro, DETI': University of Aveiro
# INFO:root:First ROR result found for 'Instituto de Telecomunicações
#  University of Aveiro, DETI': Instituto de Telecomunicações
# INFO:root:First ROR result found for ' Korea Institute for Advanced Study, 02455': Korea Institute for Advanced Study
# INFO:root:First ROR result found for 'Applied Mathematics and Computational Research Division, Lawrence Berkeley National Laboratory, Berkeley': Lawrence Berkeley National Laboratory
# INFO:root:First ROR result found for 'Pennsylvania State University, Pennsylvania State University, University Park': Pennsylvania State University
# INFO:root:First ROR result found for 'University of Minnesota, University of Minnesota, Minneapolis': University of Minnesota
# INFO:root:First ROR result found for 'Loughborough University, Loughborough University, Loughborough': Loughborough University
# INFO:root:First ROR result found for 'Technical University of Munich, Technical University of Munich, Germany; Institute for Advanced Study': Technical University of Munich
# ⚠️ Warning: Error parsing LaTeX in text: \href{http://www.ncbj.gov.pl}{National Centre for Nuclear Research}
#
# ⚠️ latex_to_unicode parse error encountered!
# Full input string:
# --------------------------------------------------
# \href{http://www.ncbj.gov.pl}{National Centre for Nuclear Research}
# --------------------------------------------------
# Error message: list index out of range
# INFO:root:First ROR result found for '\href http://www.ncbj.gov.pl  National Centre for Nuclear Research': National Centre for Nuclear Research
# INFO:root:First ROR result found for 'Ariel University, Ariel 40700, Israel
#  (E-mail: asya@ariel.ac.il)': Ariel University
# INFO:root:First ROR result found for 'Wroclaw University of Science and Technology, Wroclaw University of Science and Technology, 50-370 Wroclaw': Wrocław University of Science and Technology
# INFO:root:First ROR result found for 'Facultad de Ciencias, Universidad Nacional Autónoma de México, Investigación Científica C.U.': Universidad Nacional Autónoma de México
# INFO:root:First ROR result found for 'Utrecht University, Utrecht University, Leuvenlaan 4': Utrecht University
# INFO:root:First ROR result found for 'Asia Pacific Center for Theoretical Physics, Pohang, 37673': Asia Pacific Center for Theoretical Physics
# INFO:root:First ROR result found for 'Pohang University of Science and Technology, Pohang University of Science and Technology, Pohang': Pohang University of Science and Technology
# INFO:root:First ROR result found for 'University of Amsterdam, University of Amsterdam, 1090 GL Amsterdam': University of Amsterdam
# INFO:root:First ROR result found for 'University of British Columbia, University of British Columbia, Vancouver': University of British Columbia
# INFO:root:First ROR result found for 'National Centre for Radio Astrophysics, Tata Institute of Fundamental Research, Pune': National Centre for Radio Astrophysics
# INFO:pylatexenc.latexwalker:Ignoring parse error (tolerant parsing mode): End of input while parsing arguments of macro "\" @(1,122)
# Open LaTeX blocks:
#           @(1,122)  arguments of macro "\"
#
# INFO:root:First ROR result found for 'Ben-Gurion University of the Negev, Ben-Gurion University of the Negev, David Ben Gurion Boulevard 1': Ben-Gurion University of the Negev
# INFO:root:First ROR result found for 'University of Saskatchewan, University of Saskatchewan, city=Saskatoon': University of Saskatchewan
# INFO:root:First ROR result found for 'Missouri University of Science and Technology, Missouri University of Science and Technology, Rolla': Missouri University of Science and Technology
# INFO:root:First ROR result found for 'University of Mississippi, University of Mississippi, University': University of Mississippi
# INFO:root:First ROR result found for 'Dipartimento di Fisica, Università di Torino & INFN Sezione di Torino, via P. Giuria 1': Istituto Nazionale di Fisica Nucleare, Sezione di Torino
# INFO:root:First ROR result found for 'Eberhard-Karls University of Tübingen, Eberhard-Karls University of Tübingen, Tübingen 72076': University of Tübingen
# INFO:root:First ROR result found for 'Departament de Matemàtiques, Universitat Autònoma de Barcelona, 08193 Bellaterra': Universitat Autònoma de Barcelona
# INFO:root:First ROR result found for 'Departament d'Astronomia i Astrofísica, Universitat de València, Dr. Moliner 50': Universitat de València
# INFO:root:First ROR result found for 'University of St. Andrews, University of St. Andrews, KY16 9SS': University of St Andrews
# INFO:root:First ROR result found for 'Simon Fraser University, Simon Fraser University, Burnaby': Simon Fraser University
# INFO:root:First ROR result found for 'Centre for Molecular and Materials Science, TRIUMF, Vancouver': TRIUMF
# INFO:root:First ROR result found for 'University of California, University of California, Davis': University of California, Davis
# INFO:root:First ROR result found for 'University of California San Diego, University of California San Diego, 9500 Gilman Drive': University of California, San Diego
# INFO:root:First ROR result found for 'Northwestern University, Northwestern University, Evanston': Northwestern University
# INFO:root:First ROR result found for 'New York University, New York University, New York': New York University
# INFO:root:First ROR result found for 'Black Hole Initiative at Harvard University, Black Hole Initiative at Harvard University, 20 Garden St.': Real Colegio Complutense
# INFO:root:First ROR result found for 'Center for Astrophysics, Harvard & Smithsonian, 60 Garden St.': Center for Astrophysics Harvard & Smithsonian
# INFO:root:First ROR result found for 'Center for Relativistic Astrophysics, Georgia Institute of Technology, Howey Physics Bldg': International Center for Relativistic Astrophysics
# INFO:root:First ROR result found for 'Harvard University, Harvard University, 60 Garden Street': Harvard University
# INFO:root:First ROR result found for 'Center for Computational Astrophysics, Flatiron Institute, New York': Flatiron Institute
# INFO:root:First ROR result found for 'Columbia University, Columbia University, Pupin Hall': Columbia University
# INFO:root:First ROR result found for 'University of Maryland, University of Maryland, College Park': University of Maryland, College Park
# INFO:root:First ROR result found for 'Brandeis University, Brandeis University, Waltham': Brandeis University
# INFO:pylatexenc.latexwalker:Ignoring parse error (tolerant parsing mode): End of input while parsing arguments of macro "\" @(1,93)
# Open LaTeX blocks:
#            @(1,93)  arguments of macro "\"
#
# INFO:root:First ROR result found for 'Johns Hopkins University, Johns Hopkins University, Baltimore': Johns Hopkins University
# INFO:pylatexenc.latexwalker:Ignoring parse error (tolerant parsing mode): End of input while parsing arguments of macro "\" @(1,93)
# Open LaTeX blocks:
#            @(1,93)  arguments of macro "\"
#
# INFO:pylatexenc.latexwalker:Ignoring parse error (tolerant parsing mode): End of input while parsing arguments of macro "\" @(1,82)
# Open LaTeX blocks:
#            @(1,82)  arguments of macro "\"
#
# INFO:root:First ROR result found for 'Tata Institute of Fundamental Research, 1 Homi Bhabha Road, Mumbai 400005': Homi Bhabha National Institute
# INFO:root:First ROR result found for 'Institute of Plasma Research, Gandhinagar, Bhat': Centre of Plasma Physics - Institute for Plasma Research
# INFO:root:First ROR result found for ' Indian Institute of Technology Delhi, Hauz Khas': Indian Institute of Technology Delhi
# INFO:root:First ROR result found for 'Sandia National Laboratories, Albuquerque, NM 87185': Sandia National Laboratories
# INFO:root:First ROR result found for 'Center for Computing Research, Sandia National Laboratories, Albuquerque': Sandia National Laboratories
# INFO:root:First ROR result found for 'University of Illinois at Urbana-Champaign, University of Illinois at Urbana-Champaign, Urbana': University of Illinois Urbana-Champaign
# INFO:root:First ROR result found for 'Stockholm University and KTH Royal Institute of Technology Hannes Alfvéns väg 12, Stockholm University and KTH Royal Institute of Technology Hannes Alfvéns väg 12, SE-106 91 Stockholm': KTH Royal Institute of Technology
# INFO:root:First ROR result found for 'Institute for Physics of Microstructures, Russian Academy of Sciences, 603950 Nizhny Novgorod': Institute for Physics of Microstructures
# INFO:root:First ROR result found for 'University of Warwick': University of Warwick
# INFO:root:First ROR result found for 'INRIA Saclay': Inria Saclay - Île de France
# INFO:root:First ROR result found for 'Hampton University': Hampton University
# INFO:root:First ROR result found for 'PSL Research University, PSL Research University, CNRS': Université Paris Sciences et Lettres
# INFO:root:First ROR result found for ' College of Charleston, 66 George Street': College of Charleston
# INFO:root:First ROR result found for 'Lawrence Livermore National Laboratory, P.O. Box 808, Livermore': Lawrence Livermore National Laboratory
# INFO:root:First ROR result found for 'Harish-Chandra Research Institute, HBNI Chhatnag Road, Jhusi': Harish-Chandra Research Institute
# INFO:root:First ROR result found for 'Istanbul Technical University, Istanbul Technical University, Maslak 34469 Istanbul': Istanbul Technical University
# INFO:pylatexenc.latexwalker:Ignoring parse error (tolerant parsing mode): End of input while parsing arguments of macro "\" @(1,123)
# Open LaTeX blocks:
#           @(1,123)  arguments of macro "\"
#
# INFO:root:First ROR result found for 'Tianjin University, Tianjin University, Tianjin 300350': Tianjin University
# INFO:root:First ROR result found for 'Max Planck Institute for Astrophysics, Garching, Germany': Max Planck Institute for Astrophysics
# INFO:root:First ROR result found for ' Yale University, USA': Yale University
# INFO:root:First ROR result found for 'Stellar Astrophysics Centre, Aarhus, Denmark': Aarhus GeoSoftware (Denmark)
# INFO:root:First ROR result found for 'Anton Pannekoek Institute for Astronomy and GRAPPA, University of Amsterdam, The Netherlands': Netherlands Institute for Radio Astronomy
# INFO:root:First ROR result found for '” University of Bologna, Italy': Interporto Bologna (Italy)
# INFO:root:First ROR result found for ' University of Birmingham, UK': University of Birmingham
# INFO:root:First ROR result found for 'University of the Chinese Academy of Sciences, University of the Chinese Academy of Sciences, Beijing': University of Chinese Academy of Sciences
# INFO:root:First ROR result found for 'National Astronomical Observatories, Chinese Academy of Sciences, Beijing': National Astronomical Observatories
# INFO:root:First ROR result found for 'Institut für Kernphysik, Johannes Gutenberg-Universität, J.J. Becher-Weg 45': Johannes Gutenberg University Mainz
# INFO:root:First ROR result found for 'PRISMA + Cluster of Excellence, Johannes Gutenberg-Universität, Mainz': Johannes Gutenberg University Mainz
# INFO:root:First ROR result found for 'Michigan State University, Michigan State University, East Lansing': Michigan State University
# INFO:root:First ROR result found for 'University of Washington, University of Washington, Seattle': University of Washington
# INFO:root:First ROR result found for 'University of Innsbruck, University of Innsbruck, Innsbruck 6020': Universität Innsbruck
# INFO:root:First ROR result found for 'Institute for Quantum Optics and Quantum Information, Austrian Academy of Sciences, Innsbruck 6020': Institute for Quantum Optics and Quantum Information Innsbruck
# INFO:root:First ROR result found for 'Institut für Theoretische Physik, Universität Tübingen, Auf der Morgenstelle 14': Institute for Theoretical Physics
# INFO:root:First ROR result found for 'University of Bonn, University of Bonn, Wegelerstraße 8': University of Bonn
# INFO:root:First ROR result found for 'The University of Nottingham, The University of Nottingham, Nottingham': University of Nottingham
# INFO:root:First ROR result found for 'Tel-Aviv University, Tel-Aviv University, Tel-Aviv 69978': Tel Aviv University
# INFO:root:First ROR result found for 'Hebrew University of Jerusalem, Hebrew University of Jerusalem, Jerusalem 91904': Hebrew University of Jerusalem
# INFO:root:First ROR result found for 'Laboratoire d'Annecy-le-Vieux de Physique Théorique, CNRS – USMB, BP 110 Annecy-le-Vieux': Laboratoire d'Annecy-le-Vieux de Physique Théorique
# INFO:root:First ROR result found for 'Dipartimento di Fisica, Università di Torino, Via P. Giuria 1': University of Turin
# INFO:root:First ROR result found for 'Istituto Nazionale di Fisica Nucleare, Sezione di Torino, Via P. Giuria 1': Istituto Nazionale di Fisica Nucleare, Sezione di Torino
# INFO:root:First ROR result found for 'LAPTh, CNRS, F-74000 Annecy': Laboratoire d'Annecy-le-Vieux de Physique Théorique
# INFO:root:First ROR result found for 'Physik-Institut, Universität Zürich, CH-8057 Zürich': University of Zurich
# INFO:root:First ROR result found for 'Johannes Gutenberg University, Johannes Gutenberg University, Mainz': Johannes Gutenberg University Mainz
# INFO:root:First ROR result found for ' King’s College London, Strand': King's College London
# ✅ JSON export completed. Results saved to institution_output_with_ror.json

# %%
import json
import pandas as pd

# Load ground truth CSV
ground_truth = pd.read_csv("data/2311_with_ror.csv")

# Load extracted results JSON
with open("institution_output_with_ror.json", 'r', encoding='utf-8') as f:
    extracted_results = json.load(f)

# Preprocess ground truth: group by paper_id and collect ROR IDs
ground_truth['ROR ID'] = ground_truth['ROR ID'].fillna('').astype(str)
ground_truth['paper_id_clean'] = ground_truth['paper_id'].astype(str).str.strip().str.replace(r'v\\d+$', '', regex=True)

# Group by the cleaned paper ID
gt_rors_per_paper = (
    ground_truth.groupby('paper_id_clean')['ROR ID']
    .apply(lambda x: set(ror.strip() for ror in x if ror.strip() != ''))
    .to_dict()
)

# Evaluate paper-level accuracy and affiliation-level accuracy with details saved
correct_paper_level = 0
total_papers = 0
correct_affiliations = 0
total_affiliations = 0
evaluation_details = []

for paper_id, extracted_rors_list in extracted_results.items():
    paper_id_clean = paper_id.split('/')[-1]
    extracted_rors = set(ror_info['ROR_ID'] for ror_info in extracted_rors_list)
    gt_rors = gt_rors_per_paper.get(str(paper_id_clean), set())

    paper_correct = extracted_rors == gt_rors
    if paper_correct:
        correct_paper_level += 1

    total_papers += 1

    matched_affiliations = extracted_rors.intersection(gt_rors)
    missed_affiliations = gt_rors - extracted_rors
    extra_affiliations = extracted_rors - gt_rors

    for gt_ror in gt_rors:
        total_affiliations += 1
        if gt_ror in extracted_rors:
            correct_affiliations += 1

    evaluation_details.append({
        "paper_id": paper_id_clean,
        "ground_truth_rors": list(gt_rors),
        "extracted_rors": list(extracted_rors),
        "matched_affiliations": list(matched_affiliations),
        "missed_affiliations": list(missed_affiliations),
        "extra_affiliations": list(extra_affiliations),
        "paper_exact_match": paper_correct
    })

paper_level_accuracy = correct_paper_level / total_papers if total_papers > 0 else 0
affiliation_level_accuracy = correct_affiliations / total_affiliations if total_affiliations > 0 else 0

# Save evaluation details to JSON
with open("evaluation_details.json", "w", encoding="utf-8") as f:
    json.dump(evaluation_details, f, indent=4, ensure_ascii=False)

print(f"\n✅ Paper-level accuracy: {paper_level_accuracy * 100:.2f}% ({correct_paper_level}/{total_papers})")
print(f"✅ Affiliation-level accuracy: {affiliation_level_accuracy * 100:.2f}% ({correct_affiliations}/{total_affiliations})")
print("✅ Detailed evaluation saved to evaluation_details.json")
# Out:
# ✅ Paper-level accuracy: 20.45% (9/44)
# ✅ Affiliation-level accuracy: 51.46% (88/171)
# ✅ Detailed evaluation saved to evaluation_details.json

# %%
import requests
import json

def test_ror_query(institution_name):
    ROR_SEARCH_URL = 'https://api.ror.org/organizations'
    params = {'query': institution_name}
    
    response = requests.get(ROR_SEARCH_URL, params=params, timeout=10)
    if response.status_code == 200:
        data = response.json()
        print(f"\n🔎 Query: {institution_name}")
        print(f"Number of results: {len(data.get('items', []))}")
        for item in data.get('items', []):
            print(f"Name: {item.get('name')}")
            print(f"Score: {item.get('score')}")
            print(f"Country: {item.get('country', {}).get('country_name')}")
            print(f"ROR ID: {item.get('id')}")
            print("------")
    else:
        print(f"Request failed with status code {response.status_code}")

# Example test cases:
test_ror_query("Department of Physics, University of Illinois at Urbana-Champaign, Urbana, Illinois 61801-3080, USA")
test_ror_query("Department of Radiology, Wake Forest University School of Medicine, Winston-Salem, North Carolina, USA")
test_ror_query("Institute of Astronomy and Space Physics, Buenos Aires, Argentina")
# Out:
# 🔎 Query: Department of Physics, University of Illinois at Urbana-Champaign, Urbana, Illinois 61801-3080, USA
# Number of results: 20
# Name: University of Illinois Urbana-Champaign
# Score: None
# Country: United States
# ROR ID: https://ror.org/047426m28
# ------
# Name: Urbana University
# Score: None
# Country: United States
# ROR ID: https://ror.org/04kp3hw27
# ------
# Name: University of Illinois Chicago, Rockford campus
# Score: None
# Country: United States
# ROR ID: https://ror.org/02437s643
# ------
# Name: University of Illinois Chicago
# Score: None
# Country: United States
# ROR ID: https://ror.org/02mpq6x41
# ------
# Name: Peoria campus of the University of Illinois System
# Score: None
# Country: United States
# ROR ID: https://ror.org/02qrdc062
# ------
# Name: University of Illinois at Springfield
# Score: None
# Country: United States
# ROR ID: https://ror.org/0126qma51
# ------
# Name: Illinois Department of Agriculture
# Score: None
# Country: United States
# ROR ID: https://ror.org/00pd5rv22
# ------
# Name: Illinois Department of Transportation
# Score: None
# Country: United States
# ROR ID: https://ror.org/02vgzrk89
# ------
# Name: University of Illinois System
# Score: None
# Country: United States
# ROR ID: https://ror.org/05e94g991
# ------
# Name: Illinois Department of Human Services
# Score: None
# Country: United States
# ROR ID: https://ror.org/03gzw3461
# ------
# Name: Illinois Department of Natural Resources
# Score: None
# Country: United States
# ROR ID: https://ror.org/047g2hq96
# ------
# Name: Illinois Department of Public Health
# Score: None
# Country: United States
# ROR ID: https://ror.org/027bk5v43
# ------
# Name: State of Illinois
# Score: None
# Country: United States
# ROR ID: https://ror.org/025cbjw81
# ------
# Name: The Urbana Free Library
# Score: None
# Country: United States
# ROR ID: https://ror.org/04zd61g23
# ------
# Name: Eastern Illinois University
# Score: None
# Country: United States
# ROR ID: https://ror.org/035z2ew45
# ------
# Name: Northeastern Illinois University
# Score: None
# Country: United States
# ROR ID: https://ror.org/04edns687
# ------
# Name: Illinois State University
# Score: None
# Country: United States
# ROR ID: https://ror.org/050kcr883
# ------
# Name: Illinois Wesleyan University
# Score: None
# Country: United States
# ROR ID: https://ror.org/021aqk126
# ------
# Name: Western Illinois University
# Score: None
# Country: United States
# ROR ID: https://ror.org/02sshz518
# ------
# Name: Northern Illinois University
# Score: None
# Country: United States
# ROR ID: https://ror.org/012wxa772
# ------
#
# 🔎 Query: Department of Radiology, Wake Forest University School of Medicine, Winston-Salem, North Carolina, USA
# Number of results: 20
# Name: Winston-Salem State University
# Score: None
# Country: United States
# ROR ID: https://ror.org/049yc0897
# ------
# Name: Wake Forest University
# Score: None
# Country: United States
# ROR ID: https://ror.org/0207ad724
# ------
# Name: Winston-Salem Chamber of Commerce
# Score: None
# Country: United States
# ROR ID: https://ror.org/00y2td026
# ------
# Name: North Carolina Institute of Medicine
# Score: None
# Country: United States
# ROR ID: https://ror.org/042eghf65
# ------
# Name: North Carolina Department of Administration
# Score: None
# Country: United States
# ROR ID: https://ror.org/056w6an22
# ------
# Name: North Carolina Department of Transportation
# Score: None
# Country: United States
# ROR ID: https://ror.org/02xmd8q53
# ------
# Name: University of North Carolina School of the Arts
# Score: None
# Country: United States
# ROR ID: https://ror.org/01vfsab41
# ------
# Name: NC Department of Health and Human Services
# Score: None
# Country: United States
# ROR ID: https://ror.org/0293qmt12
# ------
# Name: North Carolina Department of Public Safety
# Score: None
# Country: United States
# ROR ID: https://ror.org/02nnywp42
# ------
# Name: North Carolina Department of Environmental Quality
# Score: None
# Country: United States
# ROR ID: https://ror.org/01ftg8r37
# ------
# Name: University of North Carolina Wilmington
# Score: None
# Country: United States
# ROR ID: https://ror.org/02t0qr014
# ------
# Name: University of North Carolina Hospitals
# Score: None
# Country: United States
# ROR ID: https://ror.org/0355zfr67
# ------
# Name: University of North Carolina System
# Score: None
# Country: United States
# ROR ID: https://ror.org/0566a8c54
# ------
# Name: Public School Forum of North Carolina
# Score: None
# Country: United States
# ROR ID: https://ror.org/04dzh1r95
# ------
# Name: Virginia Tech - Wake Forest University School of Biomedical Engineering & Sciences
# Score: None
# Country: United States
# ROR ID: https://ror.org/01q1y4t48
# ------
# Name: Winston-Salem/Forsyth County Schools
# Score: None
# Country: United States
# ROR ID: https://ror.org/0340nty70
# ------
# Name: North Carolina School of Science and Mathematics
# Score: None
# Country: United States
# ROR ID: https://ror.org/03zbydc22
# ------
# Name: University of North Carolina at Asheville
# Score: None
# Country: United States
# ROR ID: https://ror.org/017c6at71
# ------
# Name: University of North Carolina Health Care
# Score: None
# Country: United States
# ROR ID: https://ror.org/00qz24g20
# ------
# Name: University of North Carolina at Pembroke
# Score: None
# Country: United States
# ROR ID: https://ror.org/05pckj715
# ------
#
# 🔎 Query: Institute of Astronomy and Space Physics, Buenos Aires, Argentina
# Number of results: 20
# Name: Instituto de Física de Buenos Aires
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/00822yn93
# ------
# Name: Institute of Astronomy and Space Physics
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/03rq94151
# ------
# Name: Buenos Aires Institute of Technology
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/02qwadn23
# ------
# Name: University of Buenos Aires
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/0081fs513
# ------
# Name: Astronomy and Space
# Score: None
# Country: Australia
# ROR ID: https://ror.org/04ynn1b95
# ------
# Name: Hospital Británico de Buenos Aires
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/04djj4v98
# ------
# Name: Observatorio Naval Buenos Aires
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/01ae3s995
# ------
# Name: Korea Astronomy and Space Science Institute
# Score: None
# Country: South Korea
# ROR ID: https://ror.org/04g2pxh42
# ------
# Name: Buenos Aires Interdisciplinary Political Economy Institute
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/019ptgs60
# ------
# Name: Academia Nacional de Medicina
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/05k2xsz75
# ------
# Name: National University of Northwestern Buenos Aires
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/00c8e6e47
# ------
# Name: Universidad Nacional del Centro de la Provincia de Buenos Aires
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/011gakh74
# ------
# Name: Pontificia Universidad Católica Argentina
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/0422kzb24
# ------
# Name: Instituto Cardiovascular de Buenos Aires
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/05476d639
# ------
# Name: Hospital Italiano de Buenos Aires
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/00bq4rw46
# ------
# Name: Asociación Psicoanalítica de Buenos Aires
# Score: None
# Country: Argentina
# ROR ID: https://ror.org/03qtd7e32
# ------
# Name: Swedish Institute of Space Physics
# Score: None
# Country: Sweden
# ROR ID: https://ror.org/043kppn11
# ------
# Name: HUN-REN Institute of Earth Physics and Space Science
# Score: None
# Country: Hungary
# ROR ID: https://ror.org/05c9vr219
# ------
# Name: Institute of Astronomy
# Score: None
# Country: Russia
# ROR ID: https://ror.org/01whksa54
# ------
# Name: Purple Mountain Observatory
# Score: None
# Country: China
# ROR ID: https://ror.org/02eb4t121
# ------
